# %% [markdown]
# ## 2021F AML 3104 2 Neural Networks and Deep Learning
#
# ### FakeNews Detection using LSTM Neural Network
#
# *Done by,*
# **<br>Swathi Gurijila(C0790294)</br>**
# **<br>Varadharajan Kalyanaraman(C0793756)</br>**
# **<br>Vignesh Kumar Murugananthan(C0793760)</br>**
#
# #### LSTM Modeling

# %% [markdown]
# ## Why LSTM?
# An embedding layer, a convolutional layer, and a dense layer to take advantage of all of the deep learning features
# that can be helpful for our application. With Keras, we can build the model very simply.

# %%
import pandas as pd
import numpy as np

#Validation Imports
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dropout
from keras.models import load_model

#Plotting Imports
import matplotlib.pyplot as plt
import itertools

#For clean Visualization
import warnings
warnings.filterwarnings('ignore')

import time
start = time. time()

# %% [markdown]
# ## Importing clean dataset

# %%
df = pd.read_csv("../Dataset/clean_data.csv")
df = df.dropna()
df.head()
# Out:
#                                                 text  label
# 0  unit state budget fight loom republican flip f...      1
# 1  unit state militari accept transgend recruit m...      1
# 2  senior unit state republican senat let mr muel...      1
# 3  fbi russia probe help australian diplomat tip ...      1
# 4  trump want postal servic charg much amazon shi...      1

# %%
# Get the Independent Features
X = df.drop('label', axis=1)
# Get the Dependent features
y = df['label']

# %% [markdown]
# ## Vectorizing the text

# %%
# Vocabulary size
voc_size = 5000

# %%
onehot_repr = [one_hot(words, voc_size) for words in df['text'].values]
onehot_repr[:5]
# Out:
# [[2927,
#   3680,
#   3144,
#   4499,
#   1402,
#   3572,
#   3288,
#   2494,
#   1996,
#   1115,
#   2800,
#   3572,
#   3236,
#   2927,
#   3680,
#   3105,
#   189,
#   1265,
#   1155,
#   1170,
#   3008,
#   3564,
#   4594,
#   887,
#   4837,
#   517,
#   2494,
#   2800,
#   2481,
#   2307,
#   3144,
#   2895,
#   2178,
#   3496,
#   4511,
#   1819,
#   612,
#   796,
#   3572,
#   2927,
#   3680,
#   1606,
#   136,
#   3056,
#   4114,
#   1770,
#   4065,
#   3008,
#   4697,
#   649,
#   1615,
#   4844,
#   413,
#   168,
#   3746,
#   1712,
#   2274,
#   3340,
#   3690,
#   1340,
#   168,
#   1546,
#   108,
#   1095,
#   4844,
#   3144,
#   4499,
#   3789,
#   3177,
#   3449,
#   4808,
#   3779,
#   3346,
#   2167,
#   3919,
#   2943,
#   333,
#   748,
#   3572,
#   2462,
#   3496,
#   229,
#   3105,
#   1188,
#   4259,
#   308,
#   3572,
#   705,
#   2300,
#   3144,
#   2449,
#   4116,
#   413,
#   2852,
#   4693,
#   705,
#   2833,
#   2449,
#   4015,
#   107,
#   1301,
#   413,
#   1563,
#   4526,
#   2311,
#   1800,
#   4779,
#   4119,
#   326,
#   355,
#   100,
#   2304,
#   308,
#   4977,
#   2920,
#   2241,
#   4212,
#   1641,
#   2449,
#   4015,
#   107,
#   1301,
#   413,
#   4476,
#   2616,
#   3056,
#   4648,
#   2740,
#   3619,
#   3503,
#   728,
#   1498,
#   1053,
#   1563,
#   2852,
#   4212,
#   4313,
#   3462,
#   3550,
#   343,
#   4594,
#   1150,
#   1861,
#   4493,
#   2616,
#   2494,
#   2800,
#   4813,
#   304,
#   2349,
#   2493,
#   2099,
#   2822,
#   1053,
#   3056,
#   796,
#   3572,
#   189,
#   366,
#   888,
#   2547,
#   3564,
#   3963,
#   887,
#   4740,
#   906,
#   1307,
#   4844,
#   3144,
#   1036,
#   104,
#   4555,
#   3536,
#   3636,
#   1861,
#   3952,
#   4372,
#   3636,
#   3008,
#   3564,
#   845,
#   4583,
#   136,
#   2902,
#   2494,
#   2125,
#   2852,
#   2927,
#   3680,
#   1606,
#   4027,
#   2779,
#   1053,
#   1770,
#   2779,
#   1053,
#   3572,
#   887,
#   650,
#   2686,
#   942,
#   2927,
#   3680,
#   1086,
#   4555,
#   3536,
#   3636,
#   3045,
#   4494,
#   3152,
#   3963,
#   887,
#   4837,
#   3230,
#   1493,
#   3879,
#   4775,
#   2494,
#   2125,
#   650,
#   1117,
#   3493,
#   1095,
#   3919,
#   3503,
#   1606,
#   2253,
#   1641,
#   4594,
#   3462,
#   3462,
#   3952,
#   2437,
#   2779,
#   1053,
#   3572,
#   1615,
#   887,
#   3873,
#   576,
#   2927,
#   3680,
#   887,
#   4740,
#   3873,
#   3952,
#   3922,
#   2513,
#   4129,
#   4712,
#   3503,
#   2614,
#   4909,
#   4568,
#   4693,
#   4526,
#   887,
#   650,
#   3766,
#   4744,
#   3056,
#   1185,
#   973,
#   3935,
#   1217,
#   966,
#   1901,
#   859,
#   2547,
#   70,
#   517,
#   2686,
#   2309,
#   3572,
#   3389,
#   2178,
#   3572,
#   1256,
#   1901,
#   1563,
#   738,
#   1556,
#   255,
#   3503,
#   4360,
#   3002,
#   1702,
#   355,
#   263,
#   840,
#   343,
#   1728,
#   3388,
#   1563,
#   2902,
#   610,
#   4360,
#   772,
#   2852,
#   3222,
#   4568,
#   2336,
#   888,
#   388,
#   4212,
#   4964,
#   3572,
#   2686,
#   108,
#   4594,
#   887,
#   4740,
#   2462,
#   413,
#   4837,
#   154,
#   1563,
#   171,
#   3503,
#   3572,
#   948,
#   3287,
#   4687,
#   4306,
#   2289,
#   189,
#   2852,
#   3462,
#   738,
#   3144,
#   2887,
#   343,
#   853,
#   2852,
#   2727,
#   3002,
#   2289,
#   3572,
#   4840,
#   229,
#   1517,
#   1301,
#   4015,
#   107,
#   1563,
#   154,
#   413,
#   3134,
#   3449,
#   71,
#   2099,
#   4354,
#   1428,
#   1259,
#   3472,
#   308,
#   2033,
#   2044,
#   3529,
#   2178,
#   3301,
#   121,
#   2869,
#   4135,
#   2667,
#   304,
#   3646,
#   1563,
#   2304,
#   1718,
#   4808,
#   3416,
#   1271,
#   3573,
#   1461,
#   1188,
#   1053,
#   3766,
#   3902,
#   4013,
#   705,
#   3992,
#   3693,
#   3686,
#   2640,
#   2872,
#   4808,
#   3591,
#   2492,
#   593,
#   2636,
#   3993,
#   71,
#   1606,
#   3577,
#   948,
#   3033,
#   1770,
#   4398,
#   3177,
#   3449,
#   3779,
#   448,
#   2872,
#   3992,
#   3462,
#   3646,
#   152,
#   1053,
#   1340,
#   308,
#   3509,
#   2996,
#   3919,
#   2430,
#   4468,
#   3449,
#   4655,
#   4176,
#   3973,
#   4995,
#   308,
#   3572,
#   2430,
#   3516,
#   2199,
#   4476,
#   4793,
#   3503,
#   1053,
#   308,
#   4693,
#   588,
#   2996,
#   2481,
#   2022,
#   3572,
#   269,
#   4040,
#   874,
#   705,
#   3992,
#   3509,
#   3503,
#   1095,
#   523,
#   3285,
#   3509,
#   3873,
#   2188,
#   2022,
#   2276,
#   3513,
#   2946,
#   1693,
#   158,
#   3873,
#   3502,
#   1425,
#   590,
#   3285,
#   4293,
#   308,
#   4977,
#   2289,
#   374,
#   189,
#   3509],
#  [2927,
#   3680,
#   4116,
#   1062,
#   4634,
#   3181,
#   1389,
#   2650,
#   4634,
#   2099,
#   3040,
#   3412,
#   2640,
#   1172,
#   2927,
#   3680,
#   4116,
#   558,
#   1389,
#   4048,
#   4844,
#   3266,
#   2650,
#   1053,
#   1880,
#   1188,
#   4259,
#   308,
#   4977,
#   3601,
#   2678,
#   3643,
#   1171,
#   4634,
#   3214,
#   4001,
#   4844,
#   2678,
#   3266,
#   3879,
#   610,
#   3879,
#   1472,
#   1477,
#   63,
#   2873,
#   4977,
#   4293,
#   2044,
#   559,
#   4048,
#   426,
#   3266,
#   315,
#   942,
#   4116,
#   1546,
#   1062,
#   4634,
#   3181,
#   3516,
#   4555,
#   2245,
#   1391,
#   1813,
#   1053,
#   4977,
#   4406,
#   3643,
#   1391,
#   107,
#   2026,
#   4662,
#   4921,
#   1244,
#   3449,
#   2437,
#   63,
#   4314,
#   3007,
#   4285,
#   2678,
#   3429,
#   4977,
#   3601,
#   2751,
#   4344,
#   1244,
#   2701,
#   1517,
#   1188,
#   3591,
#   4911,
#   2852,
#   3266,
#   1444,
#   1813,
#   1053,
#   4114,
#   797,
#   1802,
#   2033,
#   2650,
#   1053,
#   2902,
#   3905,
#   3093,
#   1813,
#   1244,
#   3871,
#   3386,
#   308,
#   3492,
#   4634,
#   2699,
#   2656,
#   107,
#   1391,
#   3422,
#   2531,
#   1427,
#   784,
#   308,
#   4313,
#   1606,
#   918,
#   2656,
#   4634,
#   4495,
#   2718,
#   3863,
#   3181,
#   1053,
#   906,
#   4977,
#   2678,
#   3643,
#   2800,
#   929,
#   6,
#   3266,
#   1721,
#   2686,
#   4448,
#   2650,
#   1698,
#   149,
#   4141,
#   1053,
#   3038,
#   4617,
#   3266,
#   4048,
#   1391,
#   107,
#   3341,
#   1546,
#   4599,
#   4634,
#   847,
#   4116,
#   4495,
#   3516,
#   4555,
#   847,
#   2929,
#   2996,
#   4599,
#   2950,
#   3479,
#   3308,
#   4313,
#   4433,
#   372,
#   4634,
#   2781,
#   182,
#   2746,
#   517,
#   974,
#   2678,
#   3400,
#   23,
#   1721,
#   738,
#   343,
#   2437,
#   4813,
#   612,
#   2374,
#   3214,
#   773,
#   4116,
#   1259,
#   3308,
#   1053,
#   2746,
#   2307,
#   2275,
#   230,
#   663,
#   1606,
#   4574,
#   2187,
#   4784,
#   4977,
#   3802,
#   2678,
#   649,
#   1615,
#   2800,
#   4526,
#   308,
#   2026,
#   729,
#   2686,
#   3492,
#   4634,
#   2099,
#   2656,
#   4116,
#   1967,
#   2852,
#   1188,
#   3332,
#   2688,
#   3779,
#   1062,
#   308,
#   1053,
#   3902,
#   2640,
#   4116,
#   735,
#   3292,
#   3866,
#   2604,
#   4129,
#   768,
#   4634,
#   4116,
#   2686,
#   162,
#   3774,
#   4844,
#   315,
#   1273,
#   610,
#   448,
#   2946,
#   1232,
#   158,
#   3449,
#   3643,
#   1171,
#   308,
#   3214,
#   2627,
#   4406,
#   3572,
#   1188,
#   3779,
#   27,
#   315,
#   1053,
#   3214,
#   2686,
#   3789,
#   2749,
#   3196,
#   2927,
#   3680,
#   1657,
#   2654,
#   2304,
#   3591,
#   2650,
#   743,
#   4289,
#   3449,
#   2702,
#   3181,
#   2727,
#   4048,
#   1172,
#   4634,
#   847,
#   3516,
#   4555,
#   3945,
#   310,
#   2604,
#   942,
#   67,
#   847,
#   3649,
#   2686,
#   4639,
#   3346,
#   3099,
#   2686,
#   4525,
#   308,
#   4977,
#   1,
#   1053,
#   2627,
#   4253,
#   1418,
#   4635,
#   3341,
#   706,
#   4240,
#   2727,
#   2604,
#   2950,
#   3462,
#   2723,
#   4634,
#   847,
#   3193,
#   1062,
#   2699,
#   2604,
#   204,
#   4495,
#   2688,
#   4977,
#   960,
#   2124,
#   729,
#   4555,
#   4743,
#   1546,
#   1062,
#   4634,
#   3181,
#   308,
#   107,
#   706,
#   280,
#   4379,
#   4375,
#   121,
#   3516,
#   4555,
#   2178,
#   1188,
#   3214,
#   2044,
#   765,
#   308,
#   272,
#   1463,
#   2869,
#   3282,
#   4687,
#   4634,
#   3196,
#   131,
#   4977,
#   1053,
#   4844,
#   3591,
#   3214,
#   4394,
#   1085,
#   1840,
#   3349,
#   2304,
#   4634,
#   4975,
#   1967,
#   1610,
#   2688,
#   1010,
#   1408,
#   670,
#   308,
#   3575,
#   2554,
#   3449,
#   2688,
#   4977,
#   4212,
#   326,
#   76,
#   3040,
#   4634,
#   925,
#   2727,
#   4153,
#   922,
#   4394,
#   2067],
#  [3093,
#   2927,
#   3680,
#   3572,
#   2289,
#   2570,
#   770,
#   1341,
#   4129,
#   1569,
#   3217,
#   2891,
#   3177,
#   906,
#   1188,
#   308,
#   1240,
#   2943,
#   333,
#   2701,
#   2355,
#   2308,
#   2178,
#   2198,
#   517,
#   308,
#   4977,
#   2310,
#   3572,
#   168,
#   3327,
#   2440,
#   3572,
#   2289,
#   1053,
#   2481,
#   1317,
#   460,
#   2656,
#   2289,
#   1418,
#   4635,
#   33,
#   448,
#   1053,
#   1391,
#   2245,
#   1569,
#   3217,
#   3360,
#   1341,
#   3462,
#   2794,
#   906,
#   2891,
#   2355,
#   1560,
#   2308,
#   2891,
#   1641,
#   1397,
#   2891,
#   624,
#   2355,
#   1560,
#   4800,
#   460,
#   1053,
#   1770,
#   4065,
#   3008,
#   23,
#   1563,
#   3462,
#   2570,
#   770,
#   1341,
#   4129,
#   2253,
#   3196,
#   3822,
#   3196,
#   2640,
#   4903,
#   906,
#   948,
#   2455,
#   2943,
#   308,
#   333,
#   948,
#   3177,
#   198,
#   4571,
#   4095,
#   1402,
#   4793,
#   3503,
#   1095,
#   308,
#   4906,
#   2751,
#   2274,
#   4964,
#   4574,
#   3580,
#   308,
#   3341,
#   3495,
#   3952,
#   1187,
#   2198,
#   2247,
#   2689,
#   308,
#   2310,
#   3766,
#   63,
#   1499,
#   1341,
#   4768,
#   3626,
#   3572,
#   1188,
#   308,
#   2908,
#   2349,
#   4526,
#   1217,
#   1477,
#   63,
#   1680,
#   324,
#   2640,
#   1053,
#   906,
#   1341,
#   1641,
#   3151,
#   906,
#   1156,
#   2943,
#   4903,
#   3051,
#   3177,
#   308,
#   333,
#   1246,
#   3067,
#   4782,
#   610,
#   1319,
#   448,
#   2289,
#   3503,
#   1606,
#   2891,
#   3388,
#   1341,
#   1849,
#   4768,
#   948,
#   4906,
#   933,
#   231,
#   7,
#   2927,
#   3680,
#   4844,
#   3928,
#   2891,
#   108,
#   718,
#   2718,
#   308,
#   333,
#   4977,
#   1426,
#   292,
#   2891,
#   308,
#   2310,
#   2656,
#   3215,
#   906,
#   333,
#   3770,
#   2656,
#   3682,
#   2943,
#   460,
#   1053,
#   1064,
#   705,
#   2915,
#   108,
#   2727,
#   505,
#   3177,
#   308,
#   906,
#   4936,
#   582,
#   2398,
#   1492,
#   986,
#   1228,
#   1845,
#   308,
#   2310,
#   3572,
#   4903,
#   1341,
#   4782,
#   4333,
#   1680,
#   324,
#   2640,
#   2183,
#   505,
#   1922,
#   2336,
#   108,
#   231,
#   3223,
#   582,
#   308,
#   333,
#   4859,
#   3779,
#   3121,
#   1560,
#   3384,
#   4586,
#   3366,
#   906,
#   814,
#   250,
#   582,
#   308,
#   4031,
#   3717,
#   3194,
#   705,
#   4429,
#   4989,
#   612,
#   1391,
#   2245,
#   2727,
#   505,
#   3742,
#   407,
#   612,
#   2727,
#   705,
#   4429,
#   4989,
#   460,
#   1053,
#   1053,
#   906,
#   2891,
#   2929,
#   2701,
#   4233,
#   840,
#   2686,
#   4214,
#   669,
#   4682,
#   1053],
#  [108,
#   906,
#   231,
#   3993,
#   4586,
#   3366,
#   3223,
#   446,
#   308,
#   333,
#   3121,
#   1560,
#   3384,
#   3033,
#   4586,
#   3366,
#   948,
#   1240,
#   906,
#   1560,
#   4902,
#   2852,
#   538,
#   2757,
#   3717,
#   3194,
#   1680,
#   324,
#   2640,
#   2183,
#   4333,
#   2983,
#   3384,
#   3366,
#   3535,
#   2231,
#   409,
#   3049,
#   2709,
#   3227,
#   108,
#   974,
#   1877,
#   3899,
#   4020,
#   2891,
#   4420,
#   2342,
#   308,
#   333,
#   2640,
#   2183,
#   4001,
#   1265,
#   2996,
#   4586,
#   1813,
#   1095,
#   250,
#   4712,
#   3384,
#   2307,
#   1609,
#   2485,
#   2852,
#   2935,
#   1812,
#   3619,
#   1898,
#   2710,
#   1899,
#   3840,
#   3774,
#   918,
#   582,
#   2927,
#   3680,
#   4859,
#   1813,
#   1894,
#   250,
#   4586,
#   231,
#   4844,
#   3928,
#   2891,
#   4693,
#   2398,
#   4020,
#   1829,
#   343,
#   2714,
#   2398,
#   2449,
#   2640,
#   1053,
#   3384,
#   1006,
#   1085,
#   3898,
#   992,
#   4313,
#   2291,
#   2826,
#   2463,
#   3873,
#   727,
#   108,
#   2382,
#   2342,
#   2099,
#   3969,
#   953,
#   2309,
#   3459,
#   1813,
#   3412,
#   1591,
#   1361,
#   272,
#   3177,
#   308,
#   333,
#   906,
#   4793,
#   3503,
#   3598,
#   582,
#   3509,
#   333,
#   1156,
#   4212,
#   1200,
#   1282,
#   4135,
#   4906,
#   2686,
#   1680,
#   324,
#   2640,
#   1320,
#   2183,
#   3384,
#   3993,
#   960,
#   2996,
#   2757,
#   4259,
#   308,
#   4300,
#   1188,
#   1578,
#   2261,
#   4849,
#   2310,
#   2102,
#   310,
#   308,
#   3412,
#   929,
#   4859,
#   3779,
#   2282,
#   1986,
#   1240,
#   4844,
#   2891,
#   2157,
#   1569,
#   3217,
#   3360,
#   1341,
#   1851,
#   308,
#   4793,
#   3503,
#   1095,
#   4906,
#   2751,
#   3807,
#   3952,
#   3913,
#   308,
#   2310,
#   3766,
#   1499,
#   1341,
#   4768,
#   57,
#   3572,
#   1188,
#   4313,
#   3384,
#   1387,
#   967,
#   4293,
#   1383,
#   2510,
#   1341,
#   2751,
#   1191,
#   2510,
#   308,
#   4793,
#   3503,
#   2492,
#   2382,
#   1590,
#   1191,
#   2510,
#   1680,
#   324,
#   2640,
#   2183,
#   917,
#   1569,
#   3217,
#   2723,
#   2510,
#   4233,
#   1053,
#   3038,
#   1341,
#   1361,
#   3774,
#   308,
#   2918,
#   2714,
#   3384,
#   2891,
#   906,
#   2656,
#   2455,
#   2927,
#   3680,
#   2943,
#   308,
#   1053,
#   3215,
#   333,
#   4420],
#  [308,
#   705,
#   2621,
#   4495,
#   1361,
#   231,
#   3470,
#   272,
#   1188,
#   4259,
#   308,
#   517,
#   2927,
#   3680,
#   2621,
#   4495,
#   1880,
#   1361,
#   231,
#   1510,
#   3873,
#   3470,
#   3819,
#   2262,
#   1610,
#   4499,
#   1898,
#   514,
#   3034,
#   261,
#   3885,
#   2927,
#   3680,
#   3720,
#   2751,
#   3848,
#   3462,
#   3285,
#   1771,
#   3952,
#   1361,
#   3470,
#   2970,
#   2090,
#   2189,
#   3873,
#   1185,
#   3470,
#   4126,
#   3720,
#   2751,
#   862,
#   3414,
#   1361,
#   231,
#   308,
#   2558,
#   3902,
#   1188,
#   2380,
#   4697,
#   2902,
#   2291,
#   2718,
#   3963,
#   2621,
#   4495,
#   2640,
#   4633,
#   1733,
#   375,
#   1510,
#   1259,
#   3690,
#   1868,
#   2927,
#   3680,
#   2621,
#   4495,
#   2493,
#   2300,
#   4923,
#   4921,
#   826,
#   4407,
#   4844,
#   343,
#   4846,
#   887,
#   1771,
#   3204,
#   4290,
#   2710,
#   1711,
#   3873,
#   618,
#   2273,
#   1493,
#   1165,
#   3518,
#   4453,
#   4661,
#   2157,
#   4511,
#   1191,
#   839,
#   3412,
#   4007,
#   1347,
#   1188,
#   3991,
#   2621,
#   1155,
#   960,
#   2621,
#   2929,
#   895,
#   4921,
#   343,
#   826,
#   4216,
#   4572,
#   1188,
#   1560,
#   2547,
#   3905,
#   1150,
#   348,
#   3873,
#   3807,
#   2072,
#   2616,
#   2167,
#   3470,
#   1825,
#   737,
#   148,
#   2635,
#   1769,
#   2689,
#   2751,
#   514,
#   1916,
#   662,
#   3318,
#   691,
#   2710,
#   2653,
#   23,
#   148,
#   4693,
#   2519,
#   610,
#   3720,
#   1899,
#   308,
#   1978,
#   2879,
#   261,
#   23,
#   1855,
#   2380,
#   3885,
#   3952,
#   308,
#   1053,
#   3470,
#   610,
#   3720,
#   3767,
#   1682,
#   1053,
#   3470,
#   4594,
#   1618,
#   887,
#   4824,
#   4214,
#   514,
#   3518,
#   1506,
#   582,
#   3989,
#   235,
#   2954,
#   1035,
#   1632,
#   4049,
#   40,
#   2300,
#   2307,
#   1916,
#   1095,
#   4906,
#   2751,
#   2274,
#   3396,
#   1211,
#   4779,
#   3775,
#   1733,
#   3395,
#   1053,
#   308,
#   2510,
#   1895,
#   272,
#   4219,
#   514,
#   3034,
#   1320,
#   1053,
#   4589,
#   3470,
#   4813,
#   348,
#   4545,
#   4494,
#   1320,
#   1120,
#   3470,
#   1888,
#   3425,
#   874,
#   1358,
#   2989,
#   364,
#   1053,
#   3470,
#   4484,
#   845,
#   3885,
#   2995,
#   618,
#   4495,
#   2714,
#   1716,
#   2696,
#   618,
#   325,
#   1916,
#   1380,
#   4493,
#   3536,
#   3285,
#   1510,
#   4455,
#   2616,
#   4511,
#   3204,
#   4290,
#   3952,
#   3470,
#   806,
#   1916,
#   3265,
#   2616,
#   4555,
#   3201,
#   201,
#   2336,
#   3308,
#   2423,
#   2927,
#   3680,
#   2818,
#   348,
#   2989,
#   1880,
#   1079,
#   149,
#   1188,
#   1725,
#   1420,
#   2644,
#   1510,
#   2003,
#   1278,
#   3489,
#   2621,
#   4495,
#   1361,
#   4383,
#   2927,
#   375,
#   4495,
#   1420,
#   2927,
#   4808,
#   968,
#   344,
#   3948,
#   1495,
#   576,
#   2425,
#   375,
#   618,
#   4453,
#   2927,
#   3680,
#   3462,
#   231,
#   2660,
#   426,
#   1155,
#   2927,
#   3460,
#   968,
#   2686,
#   2660,
#   3720,
#   2751,
#   1315,
#   4495,
#   1053,
#   2621,
#   4495,
#   2189,
#   1003,
#   2616,
#   3470,
#   3873,
#   690,
#   3536,
#   1644,
#   1733,
#   2303,
#   918,
#   1367,
#   3952,
#   1742,
#   3690,
#   1510,
#   1868,
#   149,
#   1053,
#   2946,
#   1085,
#   1916,
#   3720,
#   2751,
#   1843,
#   4610,
#   4195,
#   3287,
#   3470,
#   3873,
#   1477,
#   2524,
#   1663,
#   3720,
#   2751,
#   231,
#   71,
#   3470,
#   2072,
#   4195,
#   2927,
#   3680,
#   2531,
#   2616,
#   968,
#   1701,
#   4289,
#   2616,
#   2710,
#   149,
#   308,
#   2510,
#   4539,
#   3530,
#   1778,
#   2621,
#   4495,
#   348,
#   1122,
#   4156,
#   1956,
#   1513,
#   2853,
#   3075,
#   4610,
#   2740,
#   3873,
#   4258,
#   1916,
#   3789,
#   2927,
#   2405,
#   4451,
#   3969,
#   918,
#   2989,
#   256,
#   2349,
#   4453,
#   2085,
#   1623,
#   3938,
#   2927,
#   3680,
#   1022,
#   1916,
#   87,
#   2458,
#   4999,
#   2621,
#   4495,
#   4784,
#   2621,
#   2929,
#   895,
#   4589,
#   2621,
#   4495,
#   146,
#   2258,
#   4129,
#   1606,
#   3470,
#   4793,
#   3503,
#   2927,
#   3680,
#   2621,
#   4495,
#   968,
#   1191,
#   2510,
#   1387,
#   2101,
#   2510,
#   308,
#   2380,
#   2710,
#   3131,
#   2183,
#   2621,
#   4495,
#   2089,
#   2072,
#   3653,
#   3285,
#   3952,
#   1036,
#   1307,
#   1005,
#   3265,
#   3285,
#   2621,
#   4495,
#   1435,
#   3412,
#   4007,
#   4610,
#   863,
#   4610,
#   1632,
#   1060,
#   1191,
#   1435,
#   3873,
#   618,
#   590,
#   2616,
#   1095,
#   2075,
#   4790,
#   3536,
#   3285,
#   2494,
#   3952,
#   1742,
#   3294,
#   3873,
#   4743,
#   4693,
#   2089,
#   2072,
#   3285,
#   1435,
#   1916,
#   1640,
#   3301,
#   1986,
#   1240,
#   2710,
#   343,
#   1616,
#   2751,
#   2183,
#   670,
#   4495,
#   4065,
#   3277,
#   2727,
#   4290,
#   1708,
#   3663,
#   1644,
#   3285,
#   1615,
#   4793,
#   2731,
#   305,
#   2621,
#   4495,
#   2026,
#   784,
#   4837,
#   4129,
#   3591,
#   2621,
#   4495,
#   960,
#   348,
#   3873,
#   618,
#   2258,
#   4129,
#   2799,
#   4495,
#   2621,
#   4495,
#   2192,
#   3536,
#   3536,
#   2616,
#   4511,
#   4129,
#   4453,
#   1510,
#   3873,
#   3346,
#   3052,
#   1615,
#   4453,
#   864,
#   2616,
#   4511,
#   1435]]

# %%
sent_length = 20
embedded_docs = pad_sequences(onehot_repr, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[3873 2188 2022 ...  374  189 3509]
#  [1010 1408  670 ...  922 4394 2067]
#  [ 407  612 2727 ...  669 4682 1053]
#  ...
#  [2191 2161 2230 ... 4720  691 4048]
#  [1000 2990 1975 ... 2780  594 3754]
#  [1839 2636 2378 ...  308 3288 1996]]

# %% [markdown]
# ## Modeling

# %%
embedding_vector_features = 40
model = Sequential()
model.add(
    Embedding(voc_size, embedding_vector_features, input_length=sent_length))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 40)            200000
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               56400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 256,501
# Trainable params: 256,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
len(embedded_docs), y.shape
# Out:
# (45405, (45405,))

# %%
X_final = np.array(embedded_docs)
y_final = np.array(y)
X_final.shape, y_final.shape
# Out:
# ((45405, 20), (45405,))

# %% [markdown]
# ### Train-Test Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final,
                                                    y_final,
                                                    test_size=0.33,
                                                    random_state=42)

# %% [markdown]
# ### Model Training

# %%
model.fit(X_train,
          y_train,
          validation_data=(X_test, y_test),
          epochs=10,
          batch_size=64)
# Out:
# Epoch 1/10
# 476/476 [==============================] - 15s 32ms/step - loss: 0.2665 - accuracy: 0.8844 - val_loss: 0.2053 - val_accuracy: 0.9189
# Epoch 2/10
# 476/476 [==============================] - 16s 33ms/step - loss: 0.1628 - accuracy: 0.9390 - val_loss: 0.2015 - val_accuracy: 0.9185
# Epoch 3/10
# 476/476 [==============================] - 14s 29ms/step - loss: 0.1326 - accuracy: 0.9505 - val_loss: 0.2138 - val_accuracy: 0.9169
# Epoch 4/10
# 476/476 [==============================] - 14s 30ms/step - loss: 0.1091 - accuracy: 0.9618 - val_loss: 0.2578 - val_accuracy: 0.9138
# Epoch 5/10
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0879 - accuracy: 0.9695 - val_loss: 0.2577 - val_accuracy: 0.9124
# Epoch 6/10
# 476/476 [==============================] - 14s 29ms/step - loss: 0.0693 - accuracy: 0.9767 - val_loss: 0.2882 - val_accuracy: 0.9088
# Epoch 7/10
# 476/476 [==============================] - 14s 29ms/step - loss: 0.0535 - accuracy: 0.9823 - val_loss: 0.3188 - val_accuracy: 0.9114
# Epoch 8/10
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0368 - accuracy: 0.9886 - val_loss: 0.3739 - val_accuracy: 0.9086
# Epoch 9/10
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0257 - accuracy: 0.9925 - val_loss: 0.4703 - val_accuracy: 0.9028
# Epoch 10/10
# 476/476 [==============================] - 14s 29ms/step - loss: 0.0194 - accuracy: 0.9941 - val_loss: 0.5270 - val_accuracy: 0.9048

# %% [markdown]
# **We tried one more model with dropouts.**

# %%
## Creating model
embedding_vector_features = 40
model = Sequential()
model.add(
    Embedding(voc_size, embedding_vector_features, input_length=sent_length))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ### Model training

# %%
model.fit(X_train,
          y_train,
          validation_data=(X_test, y_test),
          epochs=20,
          batch_size=64)
# Out:
# Epoch 1/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.2703 - accuracy: 0.8857 - val_loss: 0.2030 - val_accuracy: 0.9198
# Epoch 2/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.1716 - accuracy: 0.9347 - val_loss: 0.2031 - val_accuracy: 0.9190
# Epoch 3/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.1460 - accuracy: 0.9459 - val_loss: 0.2125 - val_accuracy: 0.9184
# Epoch 4/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.1268 - accuracy: 0.9541 - val_loss: 0.2301 - val_accuracy: 0.9166
# Epoch 5/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.1102 - accuracy: 0.9608 - val_loss: 0.2322 - val_accuracy: 0.9142
# Epoch 6/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0961 - accuracy: 0.9664 - val_loss: 0.2697 - val_accuracy: 0.9152
# Epoch 7/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0821 - accuracy: 0.9726 - val_loss: 0.2808 - val_accuracy: 0.9138
# Epoch 8/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0702 - accuracy: 0.9764 - val_loss: 0.3348 - val_accuracy: 0.9056
# Epoch 9/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0578 - accuracy: 0.9800 - val_loss: 0.3331 - val_accuracy: 0.9108
# Epoch 10/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0509 - accuracy: 0.9831 - val_loss: 0.3568 - val_accuracy: 0.9081
# Epoch 11/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0445 - accuracy: 0.9852 - val_loss: 0.4049 - val_accuracy: 0.9085
# Epoch 12/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0376 - accuracy: 0.9876 - val_loss: 0.4083 - val_accuracy: 0.9083
# Epoch 13/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0350 - accuracy: 0.9878 - val_loss: 0.4104 - val_accuracy: 0.9026
# Epoch 14/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 0.4273 - val_accuracy: 0.9047
# Epoch 15/20
# 476/476 [==============================] - 15s 32ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.4835 - val_accuracy: 0.9021
# Epoch 16/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.5229 - val_accuracy: 0.9040
# Epoch 17/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.5053 - val_accuracy: 0.9054
# Epoch 18/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0197 - accuracy: 0.9928 - val_loss: 0.5478 - val_accuracy: 0.9008
# Epoch 19/20
# 476/476 [==============================] - 15s 31ms/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 0.5110 - val_accuracy: 0.9045
# Epoch 20/20
# 476/476 [==============================] - 14s 30ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.5232 - val_accuracy: 0.8994

# %%
y_pred = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-16-fdaaf2360398>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %% [markdown]
# ## Model Evaluation

# %%
def plot_confusion_matrix(cm,
                          classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,
                 i,
                 cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Training Accuracy
Y_predict = model.predict(X_train)

#Actual Modeling
# svm_pred = classifier_svm.predict(X_test)
lstm_pred = model.predict_classes(X_test)

# print(get_metrics("LSTM", y_train, Y_predict, y_test, lstm_pred))
cm = metrics.confusion_matrix(y_test, lstm_pred)
plot_confusion_matrix(cm,
                      classes=['Fake Data', 'Real Data'],
                      title="LSTM (Dropout)")

# %%
print(lstm_pred)
# Out:
# [[1]
#  [1]
#  [0]
#  ...
#  [0]
#  [1]
#  [0]]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8994260544580887

# %% [markdown]
# ## Exporting the model

# %%
model.save('models/lstm_model_h5.h5')
